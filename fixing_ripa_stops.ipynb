# %%
import pandas as pd

# %%
data = pd.read_csv('ripa_stops_datasd.csv')
data.head()
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3457: DtypeWarning: Columns (12) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#    stop_id        ori agency  exp_years   date_stop time_stop  stopduration  \
# 0     2443  CA0371100     SD         10  2018-07-01  00:01:37            30
# 1     2444  CA0371100     SD         18  2018-07-01  00:03:34            10
# 2     2447  CA0371100     SD          1  2018-07-01  00:05:43            15
# 3     2447  CA0371100     SD          1  2018-07-01  00:05:43            15
# 4     2448  CA0371100     SD          3  2018-07-01  00:19:06             5
#
#    stop_in_response_to_cfs  officer_assignment_key  \
# 0                        0                       1
# 1                        0                       1
# 2                        1                      10
# 3                        1                      10
# ...

# %%
data.time_stop = data.time_stop.apply(lambda x: x[-8:] if len(x)>8 else x)

# %%
data = data.astype(str)

# %%
data.dtypes
# Out:
# stop_id                      object
# ori                          object
# agency                       object
# exp_years                    object
# date_stop                    object
# time_stop                    object
# stopduration                 object
# stop_in_response_to_cfs      object
# officer_assignment_key       object
# assignment                   object
# intersection                 object
# address_block                object
# land_mark                    object
# address_street               object
# highway_exit                 object
# isschool                     object
# school_name                  object
# address_city                 object
# beat                         object
# beat_name                    object
# pid                          object
# isstudent                    object
# perceived_limited_english    object
# perceived_age                object
# perceived_gender             object
# gender_nonconforming         object
# ...

# %%
data.to_csv('fixed_ripa_stops_datasd.csv')
